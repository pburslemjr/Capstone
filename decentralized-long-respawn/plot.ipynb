# %%
from matplotlib import pyplot as plt
import re

f = open("rewards_1.txt", "r")
f_2 = open("model_used_1.txt", "r")
x = []
y = []
y_2 = []

data = f.readlines()

data_2 = f_2.readlines()

rd = []
total_rew = 0.0
for i, line in enumerate(data):
    if(i<0):
        continue
    rd.append(re.findall("-?\d+\.*\d*", line))
    if(rd[-1] == []):
        break
    if(float(rd[-1][1]) > -1):#-2.5 < float(rd[-1][0]) < 2.5):
        x.append(i)
        y.append(float(rd[-1][1]))#rd[-1][0] is true_reward, rd[-1][1] is shaped reward + global, rd[-1][2] is rew_frac
        
    total_rew += y[-1]
    if(i%50 == 0):
        print(total_rew)
        y_2.append(total_rew)
        total_rew  = 0.0
print(total_rew, len(y)%50)
y_2.append(total_rew)
fig = plt.figure(figsize=(8,8))
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(range(len(y_2)),y_2)
# Out:
# -0.234375
# -9.448242200000001
# -9.05273436
# -7.163085924999999
# -5.751953135
# -5.7226562450000005
# -5.322265623
# -5.913085905
# -6.494140635000001
# -7.23144531
# -7.216796844999998
# -7.128906265000001
# -7.15820309
# -7.1874999699999975
# -6.938476549999999
# -5.8984374850000005
# -5.30761717
# -5.166015604999999
# -5.283203118000001
# -5.092773425000001
# -4.6337890900000005
# -4.85351562
# -4.282226580000001
# -4.726562490000001
# -4.638671875
# -4.5996093700000005
# -4.858398425
# -4.5166015349999995
# -4.414062498
# -4.487304685
# -1.2207031050000001 15
